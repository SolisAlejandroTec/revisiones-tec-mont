# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana - regex**
# ###**Introducción a la limpieza y procesamiento de texto.**

# %% [markdown]
# * **Nombre:** Roberto Robles Arroyo
#
# * **Matrícula:** A00493836

# %% [markdown]
# En esta actividad deberás utilizar el archivo llamado yelp_labelled.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('/content/drive/MyDrive/Colab Notebooks/MNA Procesamiento de Lenguaje Natural/Semana 2/yelp_labelled.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\t1\n',
#  'Crust is not good.\t0\n',
#  'Not tasty and the texture was just nasty.\t0\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\t1\n',
#  'The selection on the menu was great and so were the prices.\t1\n',
#  'Now I am getting angry and I want my damn pho.\t0\n',
#  "Honeslty it didn't taste THAT fresh.)\t0\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\t0\n',
#  'The fries were great too.\t1\n',
#  'A great touch.\t1\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n', así como las etiquetas de 0s y 1s que se encuentran al final de cada comentario. En esta actividad solo trabajaremos con la limpieza de datos, por lo que no requeriremos dichas etiquetas por el momento.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
docs_limpio = [re.sub(r'\t[01]\n?', '', doc) for doc in docs]

# %%
print(docs_limpio[:10])
# Out:
# ['Wow... Loved this place.', 'Crust is not good.', 'Not tasty and the texture was just nasty.', 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.', 'The selection on the menu was great and so were the prices.', 'Now I am getting angry and I want my damn pho.', "Honeslty it didn't taste THAT fresh.)", 'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.', 'The fries were great too.', 'A great touch.']

# %% [markdown]
# **NOTA: A partir de ahora, deberás trabajar con los comentarios obtenidos de esta primer pregunta.**

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
resultado_p2= re.findall(r'\w+!{2,}', ' '.join(docs_limpio))

# %%
for match in resultado_p2:
    print(match)
# Out:
# Firehouse!!!!!
# APPETIZERS!!!
# amazing!!!
# buffet!!!
# good!!
# it!!!!
# DELICIOUS!!
# amazing!!
# shawarrrrrrma!!!!!!
# yucky!!!
# steak!!!!!
# delicious!!!
# far!!
# biscuits!!!
# dry!!
# disappointing!!!
# awesome!!
# Up!!
# FLY!!!!!!!!
# here!!!
# great!!!!!!!!!!!!!!
# packed!!
# otherwise!!
# amazing!!!!!!!!!!!!!!!!!!!
# style!!
# disappointed!!

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p2)}')
# Out:
# Total de palabras encontradas: 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras o cadena de 2 o más catacteres que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra (cadena de caracteres).
#
# Indica cuántas palabras encontraste.

# %%
resultado_p3 = re.findall(r'\b[A-Z]{2,}\b', ' '.join(docs_limpio))

for match in resultado_p3:
    print(match)
# Out:
# THAT
# APPETIZERS
# WILL
# NEVER
# EVER
# STEP
# FORWARD
# IN
# IT
# AGAIN
# LOVED
# AND
# REAL
# BITCHES
# NYC
# STALE
# DELICIOUS
# WORST
# EXPERIENCE
# EVER
# ALL
# BARGAIN
# TV
# NONE
# FREEZING
# AYCE
# FLAVOR
# NEVER
# BBQ
# UNREAL
# OMG
# BETTER
# BLAND
# RUDE
# INCONSIDERATE
# MANAGEMENT
# WILL
# NEVER
# EVER
# GO
# BACK
# AND
# HAVE
# TOLD
# MANY
# PEOPLE
# WHAT
# HAD
# HAPPENED
# TOTAL
# WASTE
# OF
# TIME
# FS
# AZ
# LOVED
# CONCLUSION
# BEST
# GO
# NOW
# GC
# AVOID
# THIS
# ESTABLISHMENT
# AN
# HOUR
# NASTY
# OMG
# NO
# BEST
# THE
# OWNERS
# REALLY
# REALLY
# PERFECT
# SCREAMS
# LEGIT
# MGM
# BEST
# FLY
# FLY
# FANTASTIC
# GREAT
# OK
# WAY
# MUST
# HAVE
# OK
# OVERPRICED
# BARE
# HANDS
# WEAK
# SHOULD
# RI
# VERY
# NOT

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p3)}')
# Out:
# Total de palabras encontradas: 96

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
resultado_p4 = [doc for doc in docs_limpio if re.fullmatch(r'[^a-z]+', doc)]

for match in resultado_p4:
    print(match)
# Out:
# DELICIOUS!!
# RUDE & INCONSIDERATE MANAGEMENT.
# WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.
# TOTAL WASTE OF TIME.
# AVOID THIS ESTABLISHMENT!

# %%
print(f'\nTotal de comentarios encontrados: {len(resultado_p4)}')
# Out:
# Total de comentarios encontrados: 5

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
resultado_p5 = re.findall(r'\w*[áéíóú]\w*', ' '.join(docs_limpio))

for match in resultado_p5:
    print(match)
# Out:
# fiancé
# Café
# puréed

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p5)}')
# Out:
# Total de palabras encontradas: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
resultado_p6 = re.findall(r'\$\d+(?:\.\d+)?', ' '.join(docs_limpio))

for match in resultado_p6:
    print(match)
# Out:
# $20
# $4.00
# $17
# $3
# $35
# $7.85
# $12
# $11.99

# %%
print(f'\nTotal de cantidades numéricas encontradas: {len(resultado_p6)}')
# Out:
# Total de cantidades numéricas encontradas: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love" (amor). No deberá importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra, como repetir letras por ejemplo.
#
# Observa que deben ser variantes de la palabra love (amor) y no variantes de dicha cadena de caracteres.
#
# Indica cuántos resultados obtuviste.

# %%
resultado_p7 = re.findall(r'\b[lL]+[oO]+[vV]+[eE]+[a-zA-Z]*\b', ' '.join(docs_limpio))

for match in resultado_p7:
    print(match)
# Out:
# Loved
# loved
# Loved
# love
# loves
# LOVED
# lovers
# love
# lovers
# Love
# loved
# loved
# love
# love
# love
# loved
# love
# loved
# Love
# LOVED
# love
# lovely
# love
# lovely
# love
# lover
# loved
# love
# love
# love
# love
# love
# love
# love
# love

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p7)}')
# Out:
# Total de palabras encontradas: 35

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras que sean variantes de las palabras en inglés "so" y "good", y que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Observa que solo debes incluir variantes de estas palabras en inglés y no de dichas cadenas de caracteres.
#
# Indica además cuántas encontraste.

# %%
resultado_p8 = re.findall(r'\bso{2,}\b|\b[gG][oO]{3,}[dD]\b', ' '.join(docs_limpio), re.IGNORECASE)

for match in resultado_p8:
    print(match)
# Out:
# Sooooo
# soooo
# soooooo
# soooo

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p8)}')
# Out:
# Total de palabras encontradas: 4

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 12 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
resultado_p9 = [w for w in re.findall(r'\b[a-zA-Z]+\b', ' '.join(docs_limpio)) if len(w) > 12]

for match in resultado_p9:
    print(match)
# Out:
# recommendation
# establishment
# underwhelming
# disappointing
# disappointing
# Unfortunately
# accommodations
# recommendation
# shawarrrrrrma
# INCONSIDERATE
# disappointment
# establishment
# extraordinary
# ESTABLISHMENT
# disappointing
# recommendation
# establishment
# Unfortunately
# Wienerschnitzel
# unfortunately
# Mediterranean
# unprofessional
# disappointing
# unexperienced
# Disappointing
# WAAAAAAyyyyyyyyyy
# disappointment
# disappointment
# deuchebaggery
# disappointment
# Unfortunately
# disapppointment
# circumstances
# underwhelming

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p9)}')
# Out:
# Total de palabras encontradas: 34

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras (caracteres alfabéticos) que inician con una letra mayúscula y terminan con una minúscula, pero donde además dicha palabra no sea la primera palabra del comentario (string).
#
# Indica la cantidad de resultados obtenidos.

# %%
resultado_p10 = []
for doc in docs_limpio:
    matches = re.findall(r'(?<=\s)[A-Z][a-zA-Z]*[a-z]\b', doc)
    resultado_p10.extend(matches)

for match in resultado_p10:
    print(match)
# Out:
# Loved
# May
# Rick
# Steve
# Cape
# Cod
# Vegas
# Burrittos
# Blah
# The
# They
# Mexican
# Luke
# Our
# Hiro
# Firehouse
# Greek
# Greek
# Heart
# Attack
# Grill
# Vegas
# Dos
# Gringos
# Jeff
# Really
# Excalibur
# Very
# Bad
# Customer
# Service
# Vegas
# Rice
# Company
# Pho
# Hard
# Rock
# Casino
# Buffet
# Tigerlilly
# Yama
# Thai
# Indian
# Not
# Vegas
# Lox
# Subway
# Subway
# Vegas
# Vegas
# Mandalay
# Bay
# Great
# Voodoo
# Phoenix
# Vegas
# Khao
# Soi
# Lemon
# Joey
# Valley
# Phoenix
# Magazine
# Pho
# Fridays
# Tasty
# Jamaican
# Bisque
# Bussell
# Sprouts
# Risotto
# Filet
# Otto
# Yeah
# Honestly
# Not
# Also
# Vegas
# Greek
# Vegas
# Veggitarian
# Madison
# Ironman
# Jenni
# Pho
# Bachi
# Burger
# Pizza
# Salads
# They
# Yelpers
# Bachi
# Service
# English
# Pizza
# Hut
# Seat
# Standard
# Thai
# Tucson
# Vegas
# Chipotle
# Gordon
# Ramsey
# Steak
# Vegas
# Outstanding
# Best
# Food
# Lobster
# Bisque
# Vegas
# Eggplant
# Green
# Bean
# Halibut
# Vegas
# Vegas
# ...

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p10)}')
# Out:
# Total de palabras encontradas: 266

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían, ya que incluyen algún espacio en blanco.
#
# Indica la cantidad de resultados obtenidos.

# %%
resultado_p11 = re.findall(r'\b\w+(?:-\w+)+\b', ' '.join(docs_limpio))

for match in resultado_p11:
    print(match)
# Out:
# flat-lined
# hands-down
# must-stop
# sub-par
# Service-check
# in-house
# been-stepped-in-and-tracked-everywhere
# multi-grain
# to-go
# non-customer
# High-quality
# sit-down
# over-whelm
# low-key
# non-fancy
# golden-crispy
# over-priced
# over-hip
# under-services

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p11)}')
# Out:
# Total de palabras encontradas: 19

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan con la conjugación en inglés "ing" o "ed".
#
# No deben importar mayúsculas o minúsculas.
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
resultado_p12 = re.findall(r'\b[a-zA-Z]+(?:ing|ed)\b', ' '.join(docs_limpio), re.IGNORECASE)

for match in resultado_p12:
    print(match)
# Out:
# Loved
# Stopped
# during
# loved
# getting
# being
# ended
# being
# overpriced
# tried
# disgusted
# shocked
# recommended
# amazing
# performed
# red
# asked
# running
# overwhelmed
# redeeming
# grossed
# melted
# getting
# provided
# thing
# cooked
# dressing
# refreshing
# ordered
# running
# realized
# Loved
# lined
# cooked
# ripped
# ripped
# petrified
# amazing
# included
# expected
# nothing
# appalling
# seasoned
# cheated
# wasting
# eating
# going
# Coming
# experiencing
# underwhelming
# walked
# smelled
# eating
# raving
# tailored
# spring
# unsatisfying
# amazing
# Everything
# disappointing
# dining
# flirting
# arrived
# roasted
# added
# thing
# coming
# LOVED
# cooked
# playing
# passed
# ordering
# arriving
# liked
# disappointing
# managed
# served
# preparing
# loving
# liking
# reviewing
# venturing
# overpriced
# including
# during
# checked
# disappointed
# red
# decorated
# changing
# going
# considering
# served
# coming
# watched
# greeted
# seated
# ...

# %%
print(f'\nTotal de palabras encontradas: {len(resultado_p12)}')
# Out:
# Total de palabras encontradas: 618

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos, incluyendo algún tipo de acentuación. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
docs_limpio2 = []

for doc in docs_limpio:
    doc = re.sub(r'[^a-zA-ZáéíóúÁÉÍÓÚ\s]', '', doc)  # solo caracteres alfabéticos y acentuados
    doc = doc.lower()                                   # convertir a minúsculas
    doc = re.sub(r'\s+', ' ', doc).strip()             # eliminar espacios adicionales
    docs_limpio2.append(doc)

# %%
for doc in docs_limpio2[:10]:
    print(doc)
# Out:
# wow loved this place
# crust is not good
# not tasty and the texture was just nasty
# stopped by during the late may bank holiday off rick steve recommendation and loved it
# the selection on the menu was great and so were the prices
# now i am getting angry and i want my damn pho
# honeslty it didnt taste that fresh
# the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer
# the fries were great too
# a great touch

# %% [markdown]
# *   **Pregunta 14.**
#
# Supongamos que en un primer análisis básico consideramos como nuestro nuevo corpus el texto obtenido después del proceso de limpieza del ejercicio anterior.
#
# A partir de este nuevo corpus consideraremos cada palabra (cadena de caracteres) resultante como los "tokens" de nuestro estudio.
#
# Y a partir de este documento tokenizado generamos nuestro diccionario de tokens.
#
# ¿Cuántos tokens diferentes tiene nuestro diccionario?

# %%
tokens = [token for doc in docs_limpio2 for token in doc.split()]
diccionario = list(set(tokens))

# %%
print(f'Total de tokens: {len(tokens)}')
print(f'Total de tokens únicos (diccionario): {len(diccionario)}')
# Out:
# Total de tokens: 10777
# Total de tokens únicos (diccionario): 2051

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras denominado "stopwords", es decir, las palabras (cadenas de caracteres) que tienen frecuencias muy altas, pero que no aportan mucho valor para el significado/entendimiento de cada comentario.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera.
#
# * **15a.** Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior. Imprime los primeros 5 comentarios resultantes.
#
# * **15b.** ¿De qué tamaño quedó tu documento? Es decir, ¿cuántos tokens tiene finalmente todo tu nuevo documento de comentarios procesado?
#
# * **15c.** ¿Cuántos tokens diferentes quedaron? Es decir, ¿cuántos tokens únicos tiene tu vocabulario final?

# %%
# Debes considerar la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']
docs_sin_sw = [' '.join([token for token in doc.split() if token not in mis_stopwords]) for doc in docs_limpio2]

for doc in docs_sin_sw[:5]:
    print(doc)
# Out:
# wow loved place
# crust not good
# not tasty texture nasty
# stopped late may bank holiday off rick steve recommendation loved
# selection menu great prices

# %%
tokens_sin_sw = [token for doc in docs_sin_sw for token in doc.split()]
print(f'Total de tokens: {len(tokens_sin_sw)}')
# Out:
# Total de tokens: 5776

# %%
vocabulario_final = set(tokens_sin_sw)
print(f'Total de tokens únicos (vocabulario final): {len(vocabulario_final)}')
# Out:
# Total de tokens únicos (vocabulario final): 1941

# %% [markdown]
# *   **Pregunta 15. Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Esta actividad ha sido muy entretenida, ilustrativa y enriquecedora.
#
# Nos ha demostrado que la limpieza y procesamiento de texto es fundamental para poder obtener información muy útil para ser analizada. Efectivamente cada vez escribimos más alejados de las palabras que hoy existen en los múltiples diccionarios disponibles, ya sea por practicidad, comodidad, ignorancia, urgencia o una suma de las anteriores; y es fundamental al analizar el texto tener esto considerado porque cada vez va a ser más complejo de entender el texto dado el contexto, la región, el idioma, la edad, los modismos, entre otros factores.
#
# Si bien es cierto los comandos de Regex en Python no son complejos en sí, es importante entender y aplicar las reglas para poder limpiar y analizar la información. Esta tarea me obligó a analizar, entender la conjugación y mezcla de reglas para el fin deseado.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
