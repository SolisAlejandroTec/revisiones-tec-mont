# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana - regex**
# ###**Introducción a la limpieza y procesamiento de texto.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# * **Nombre: Judith Martínez Peña*
#
# * **Matrícula: A01169600**

# %% [markdown]
# En esta actividad deberás utilizar el archivo llamado yelp_labelled.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('yelp_labelled.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[0:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\t1\n',
#  'Crust is not good.\t0\n',
#  'Not tasty and the texture was just nasty.\t0\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\t1\n',
#  'The selection on the menu was great and so were the prices.\t1\n',
#  'Now I am getting angry and I want my damn pho.\t0\n',
#  "Honeslty it didn't taste THAT fresh.)\t0\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\t0\n',
#  'The fries were great too.\t1\n',
#  'A great touch.\t1\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n', así como las etiquetas de 0s y 1s que se encuentran al final de cada comentario. En esta actividad solo trabajaremos con la limpieza de datos, por lo que no requeriremos dichas etiquetas por el momento.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
# Abrir el archivo y leemos las líneas
with open("yelp_labelled.txt", "r", encoding="utf-8") as file:
    comentarios = file.readlines()

# Eliminamos saltos de línea '\n' y etiquetas finales 0/1
comentarios_limpios = []

for comentario in comentarios:
    comentario = comentario.strip()          # elimina \n
    comentario = re.sub(r"\t[01]$", "", comentario)  # elimina etiqueta final
    comentarios_limpios.append(comentario)

# Imprimir los primeros 10 comentarios
for comentario in comentarios_limpios[:10]:
    print(comentario)
# Out:
# Wow... Loved this place.
# Crust is not good.
# Not tasty and the texture was just nasty.
# Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.
# The selection on the menu was great and so were the prices.
# Now I am getting angry and I want my damn pho.
# Honeslty it didn't taste THAT fresh.)
# The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.
# The fries were great too.
# A great touch.

# %% [markdown]
# **NOTA: A partir de ahora, deberás trabajar con los comentarios obtenidos de esta primer pregunta.**

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
import re

# Lista para guardar resultados
resultados = []

# Regex: palabra + 2 o más !
patron = r"\b\w+!{2,}"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# Firehouse!!!!!
# APPETIZERS!!!
# amazing!!!
# buffet!!!
# good!!
# it!!!!
# DELICIOUS!!
# amazing!!
# shawarrrrrrma!!!!!!
# yucky!!!
# steak!!!!!
# delicious!!!
# far!!
# biscuits!!!
# dry!!
# disappointing!!!
# awesome!!
# Up!!
# FLY!!!!!!!!
# here!!!
# great!!!!!!!!!!!!!!
# packed!!
# otherwise!!
# amazing!!!!!!!!!!!!!!!!!!!
# style!!
# disappointed!!
#
# Total encontrados: 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras o cadena de 2 o más catacteres que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra (cadena de caracteres).
#
# Indica cuántas palabras encontraste.

# %%
import re

resultados = []

# Regex: palabras en mayúsculas de al menos 2 letras
patron = r"\b[A-Z]{2,}\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# THAT
# APPETIZERS
# WILL
# NEVER
# EVER
# STEP
# FORWARD
# IN
# IT
# AGAIN
# LOVED
# AND
# REAL
# BITCHES
# NYC
# STALE
# DELICIOUS
# WORST
# EXPERIENCE
# EVER
# ALL
# BARGAIN
# TV
# NONE
# FREEZING
# AYCE
# FLAVOR
# NEVER
# BBQ
# UNREAL
# OMG
# BETTER
# BLAND
# RUDE
# INCONSIDERATE
# MANAGEMENT
# WILL
# NEVER
# EVER
# GO
# BACK
# AND
# HAVE
# TOLD
# MANY
# PEOPLE
# WHAT
# HAD
# HAPPENED
# TOTAL
# WASTE
# OF
# TIME
# FS
# AZ
# LOVED
# CONCLUSION
# BEST
# GO
# NOW
# GC
# AVOID
# THIS
# ESTABLISHMENT
# AN
# HOUR
# NASTY
# OMG
# NO
# BEST
# THE
# OWNERS
# REALLY
# REALLY
# PERFECT
# SCREAMS
# LEGIT
# MGM
# BEST
# FLY
# FLY
# FANTASTIC
# GREAT
# OK
# WAY
# MUST
# HAVE
# OK
# OVERPRICED
# BARE
# HANDS
# WEAK
# SHOULD
# RI
# VERY
# NOT
#
# Total encontrados: 96

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
import re

resultados = []

for comentario in comentarios_limpios:
    # Extraemos solo letras
    letras = re.sub(r"[^A-Za-z]", "", comentario)

    # Validamos que tenga letras y que todas sean mayúsculas
    if letras and letras.isupper():
        resultados.append(comentario)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# DELICIOUS!!
# RUDE & INCONSIDERATE MANAGEMENT.
# WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.
# TOTAL WASTE OF TIME.
# AVOID THIS ESTABLISHMENT!
#
# Total encontrados: 5

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
import re

resultados = []

# Regex: palabras que contienen al menos una vocal acentuada
patron = r"\b\w*[áéíóúÁÉÍÓÚ]\w*\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# fiancé
# Café
# puréed
#
# Total encontrados: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
import re

resultados = []

# Regex: $ seguido de números y opcional decimal
patron = r"\$\d+(?:\.\d+)?"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# $20
# $4.00
# $17
# $3
# $35
# $7.85
# $12
# $11.99
#
# Total encontrados: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love" (amor). No deberá importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra, como repetir letras por ejemplo.
#
# Observa que deben ser variantes de la palabra love (amor) y no variantes de dicha cadena de caracteres.
#
# Indica cuántos resultados obtuviste.

# %%
import re

resultados = []

# Regex para variantes de "love"
patron = r"\blo+ve\w*\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario, re.IGNORECASE)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# Loved
# loved
# Loved
# love
# loves
# LOVED
# lovers
# love
# lovers
# Love
# loved
# loved
# love
# love
# love
# loved
# love
# loved
# Love
# LOVED
# love
# lovely
# love
# lovely
# love
# lover
# loved
# love
# love
# love
# love
# love
# love
# love
# love
#
# Total encontrados: 35

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras que sean variantes de las palabras en inglés "so" y "good", y que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Observa que solo debes incluir variantes de estas palabras en inglés y no de dichas cadenas de caracteres.
#
# Indica además cuántas encontraste.

# %%
import re

resultados = []

# Regex:
# so con 2+ o  → so{2,}
# good con 3+ o → go{3,}d
patron = r"\bso{2,}\b|\bgo{3,}d\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario, re.IGNORECASE)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# Sooooo
# soooo
# soooooo
# soooo
#
# Total encontrados: 4

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 12 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
import re

resultados = []

# Regex: palabras solo con letras y longitud > 12
patron = r"\b[A-Za-z]{13,}\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad de resultados
print("\nTotal encontrados:", len(resultados))
# Out:
# recommendation
# establishment
# underwhelming
# disappointing
# disappointing
# Unfortunately
# accommodations
# recommendation
# shawarrrrrrma
# INCONSIDERATE
# disappointment
# establishment
# extraordinary
# ESTABLISHMENT
# disappointing
# recommendation
# establishment
# Unfortunately
# Wienerschnitzel
# unfortunately
# Mediterranean
# unprofessional
# disappointing
# unexperienced
# Disappointing
# WAAAAAAyyyyyyyyyy
# disappointment
# disappointment
# deuchebaggery
# disappointment
# Unfortunately
# disapppointment
# circumstances
# underwhelming
#
# Total encontrados: 34

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras (caracteres alfabéticos) que inician con una letra mayúscula y terminan con una minúscula, pero donde además dicha palabra no sea la primera palabra del comentario (string).
#
# Indica la cantidad de resultados obtenidos.

# %%
import re

resultados = []

# Regex: palabra que inicia con mayúscula y termina en minúscula
patron = r"\b[A-Z][a-z]+\b"

for comentario in comentarios_limpios:
    # separar palabras
    palabras = comentario.split()

    # excluir la primera palabra
    resto_palabras = palabras[1:]

    for palabra in resto_palabras:
        # limpiar signos (.,! etc)
        palabra_limpia = re.sub(r"[^A-Za-z]", "", palabra)

        if re.fullmatch(patron, palabra_limpia):
            resultados.append(palabra_limpia)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad
print("\nTotal encontrados:", len(resultados))
# Out:
# Loved
# May
# Rick
# Steve
# Cape
# Cod
# Vegas
# Burrittos
# Blah
# The
# They
# Mexican
# Luke
# Our
# Hiro
# Firehouse
# Greek
# Greek
# Heart
# Attack
# Grill
# Vegas
# Dos
# Gringos
# Jeff
# Really
# Excalibur
# Very
# Bad
# Customer
# Service
# Ive
# Vegas
# Rice
# Company
# Pho
# Hard
# Rock
# Casino
# Buffet
# Tigerlilly
# Yama
# Thai
# Indian
# Not
# Ill
# Im
# Vegas
# Lox
# Subway
# Subway
# Vegas
# Vegas
# Mandalay
# Bay
# Great
# Voodoo
# Id
# Phoenix
# Vegas
# Khao
# Soi
# Im
# Lemon
# Joeys
# Valley
# Phoenix
# Magazine
# Pho
# Fridays
# Ive
# Tasty
# Jamaican
# Bisque
# Bussell
# Sprouts
# Risotto
# Filet
# Otto
# Yeah
# Honestly
# Ms
# Not
# Also
# Vegas
# Greek
# Vegas
# Veggitarian
# Madison
# Ironman
# Jenni
# Pho
# Bachi
# Burger
# Pizza
# Salads
# They
# Yelpers
# Bachi
# Servicecheck
# Id
# English
# Ive
# Ive
# Pizza
# Hut
# Seat
# Gold
# Standard
# Thai
# Tucson
# Ive
# Vegasthere
# Chipotle
# Baseball
# Gordon
# Ramseys
# Steak
# Vegas
# Ive
# Outstanding
# ...

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían, ya que incluyen algún espacio en blanco.
#
# Indica la cantidad de resultados obtenidos.

# %%
import re

resultados = []

# Regex: palabras unidas por guion sin espacios
patron = r"\b[A-Za-z]+(?:-[A-Za-z]+)+\b"

for comentario in comentarios_limpios:
    matches = re.findall(patron, comentario)
    resultados.extend(matches)

# Imprimir resultados
for r in resultados:
    print(r)

# Cantidad
print("\nTotal encontrados:", len(resultados))
# Out:
# flat-lined
# hands-down
# must-stop
# sub-par
# Service-check
# in-house
# been-stepped-in-and-tracked-everywhere
# multi-grain
# to-go
# non-customer
# High-quality
# sit-down
# over-whelm
# low-key
# non-fancy
# golden-crispy
# over-priced
# over-hip
# under-services
#
# Total encontrados: 19

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan con la conjugación en inglés "ing" o "ed".
#
# No deben importar mayúsculas o minúsculas.
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
import re

palabras_ing = []
palabras_ed = []

# Regex
patron_ing = r"\b[A-Za-z]+ing\b"
patron_ed = r"\b[A-Za-z]+ed\b"

for comentario in comentarios_limpios:
    palabras_ing.extend(re.findall(patron_ing, comentario, re.IGNORECASE))
    palabras_ed.extend(re.findall(patron_ed, comentario, re.IGNORECASE))

# Imprimir resultados
print("Palabras que terminan en 'ing':")
for p in palabras_ing:
    print(p)

print("\nTotal 'ing':", len(palabras_ing))


print("\nPalabras que terminan en 'ed':")
for p in palabras_ed:
    print(p)

print("\nTotal 'ed':", len(palabras_ed))
# Out:
# Palabras que terminan en 'ing':
# during
# getting
# being
# being
# amazing
# running
# redeeming
# getting
# thing
# dressing
# refreshing
# running
# amazing
# nothing
# appalling
# wasting
# eating
# going
# Coming
# experiencing
# underwhelming
# eating
# raving
# spring
# unsatisfying
# amazing
# Everything
# disappointing
# dining
# flirting
# thing
# coming
# playing
# ordering
# arriving
# disappointing
# preparing
# loving
# liking
# reviewing
# venturing
# including
# during
# changing
# going
# considering
# coming
# going
# everything
# looking
# dressing
# dining
# Everything
# amazing
# judging
# maintaining
# asking
# having
# something
# lacking
# Interesting
# preparing
# missing
# feeling
# exceeding
# inviting
# climbing
# waiting
# coming
# being
# lacking
# going
# amazing
# dealing
# annoying
# falling
# sporting
# amazing
# providing
# building
# FREEZING
# lighting
# going
# nothing
# working
# eating
# dressing
# being
# outstanding
# getting
# amazing
# ...

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos, incluyendo algún tipo de acentuación. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
import re

comentarios_procesados = []

for comentario in comentarios_limpios:

    # 1. Convertir a minúsculas
    comentario = comentario.lower()

    # 2. Eliminar todo lo que NO sea letra (incluye acentos)
    comentario = re.sub(r"[^a-záéíóúüñ\s]", "", comentario)

    # 3. Eliminar espacios extra
    comentario = re.sub(r"\s+", " ", comentario).strip()

    comentarios_procesados.append(comentario)

# Imprimir los primeros 10 comentarios
for c in comentarios_procesados[:10]:
    print(c)
# Out:
# wow loved this place
# crust is not good
# not tasty and the texture was just nasty
# stopped by during the late may bank holiday off rick steve recommendation and loved it
# the selection on the menu was great and so were the prices
# now i am getting angry and i want my damn pho
# honeslty it didnt taste that fresh
# the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer
# the fries were great too
# a great touch

# %% [markdown]
# *   **Pregunta 14.**
#
# Supongamos que en un primer análisis básico consideramos como nuestro nuevo corpus el texto obtenido después del proceso de limpieza del ejercicio anterior.
#
# A partir de este nuevo corpus consideraremos cada palabra (cadena de caracteres) resultante como los "tokens" de nuestro estudio.
#
# Y a partir de este documento tokenizado generamos nuestro diccionario de tokens.
#
# ¿Cuántos tokens diferentes tiene nuestro diccionario?

# %%
tokens = []

# Tokenizar (separar por palabras)
for comentario in comentarios_procesados:
    palabras = comentario.split()
    tokens.extend(palabras)

# Crear diccionario de tokens únicos
tokens_unicos = set(tokens)

# Cantidad de tokens diferentes
print("Cantidad de tokens diferentes:", len(tokens_unicos))
# Out:
# Cantidad de tokens diferentes: 2051

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras denominado "stopwords", es decir, las palabras (cadenas de caracteres) que tienen frecuencias muy altas, pero que no aportan mucho valor para el significado/entendimiento de cada comentario.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera.
#
# * **15a.** Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior. Imprime los primeros 5 comentarios resultantes.
#
# * **15b.** ¿De qué tamaño quedó tu documento? Es decir, ¿cuántos tokens tiene finalmente todo tu nuevo documento de comentarios procesado?
#
# * **15c.** ¿Cuántos tokens diferentes quedaron? Es decir, ¿cuántos tokens únicos tiene tu vocabulario final?

# %%
# Debes considerar la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
# Lista de stopwords
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves',
'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs',
'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these',
'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have',
'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the',
'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at',
'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through',
'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once',
'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both',
'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own',
'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just',
'should', 'now', 'll']

comentarios_sin_stopwords = []

for comentario in comentarios_procesados:
    palabras = comentario.split()

    # eliminar stopwords
    palabras_filtradas = [p for p in palabras if p not in mis_stopwords]

    comentario_limpio = " ".join(palabras_filtradas)
    comentarios_sin_stopwords.append(comentario_limpio)

# Imprimir primeros 5
for c in comentarios_sin_stopwords[:5]:
    print(c)
# Out:
# wow loved place
# crust not good
# not tasty texture nasty
# stopped late may bank holiday off rick steve recommendation loved
# selection menu great prices

# %%
tokens_finales = []

for comentario in comentarios_sin_stopwords:
    tokens_finales.extend(comentario.split())

print("Total de tokens:", len(tokens_finales))
# Out:
# Total de tokens: 5776

# %%
tokens_unicos_final = set(tokens_finales)

print("Tokens únicos:", len(tokens_unicos_final))
# Out:
# Tokens únicos: 1941

# %% [markdown]
# *   **Pregunta 15. Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Durante esta actividad pude comprender la importancia de la limpieza y preparación de datos en el procesamiento de lenguaje natural (NLP). Aunque en un inicio el texto puede parecer sencillo, al analizarlo se observa que contiene ruido como signos de puntuación, mayúsculas inconsistentes, espacios adicionales y palabras irrelevantes (stopwords) que pueden afectar el desempeño de los modelos.
#
# El uso de expresiones regulares (regex) resultó fundamental para identificar patrones específicos dentro del texto, como palabras en mayúsculas, cantidades monetarias o variaciones de ciertas palabras. Esto me permitió entender cómo se pueden extraer características relevantes de un corpus de manera eficiente.
#
# Asimismo, el proceso de normalización del texto (pasar a minúsculas, eliminar caracteres especiales y espacios extra) facilita la estandarización de los datos, lo cual es clave para evitar duplicidades y mejorar el análisis posterior.
#
# Finalmente, al eliminar las stopwords y generar el diccionario de tokens, pude observar cómo se reduce significativamente el tamaño del corpus, conservando únicamente las palabras con mayor valor semántico. Esto es especialmente útil en tareas como clasificación de texto, análisis de sentimientos o modelado de lenguaje.
#
# En conclusión, esta actividad me ayudó a entender que una correcta preparación de los datos es una etapa crítica en NLP, ya que impacta directamente en la calidad y precisión de los modelos que se desarrollen posteriormente.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
